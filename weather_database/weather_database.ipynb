# %%
# Import the dependencies.
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Import the requests library.
import requests

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import pandas as pd

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | faya
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | namibe
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | rio formoso
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | tiksi
# Processing Record 14 of Set 1 | puerto leguizamo
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | witbank
# Processing Record 17 of Set 1 | sabha
# Processing Record 18 of Set 1 | aklavik
# Processing Record 19 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 1 | tazovskiy
# Processing Record 21 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 1 | san carlos de bariloche
# Processing Record 23 of Set 1 | adolfo lopez mateos
# Processing Record 24 of Set 1 | luau
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | upernavik
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | broome
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | provideniya
# Processing Record 33 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 1 | yendi
# Processing Record 35 of Set 1 | cabot
# Processing Record 36 of Set 1 | yima
# Processing Record 37 of Set 1 | saint anthony
# Processing Record 38 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 1 | natchitoches
# Processing Record 40 of Set 1 | kloulklubed
# Processing Record 41 of Set 1 | muana
# Processing Record 42 of Set 1 | sur
# Processing Record 43 of Set 1 | lebu
# Processing Record 44 of Set 1 | ketchikan
# Processing Record 45 of Set 1 | geraldton
# Processing Record 46 of Set 1 | clyde river
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | vardo
# Processing Record 49 of Set 1 | fortuna
# Processing Record 50 of Set 1 | nanortalik
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | saint-philippe
# Processing Record 4 of Set 2 | hamilton
# Processing Record 5 of Set 2 | lompoc
# Processing Record 6 of Set 2 | puerto ayora
# Processing Record 7 of Set 2 | condado
# Processing Record 8 of Set 2 | victoria
# Processing Record 9 of Set 2 | kosonsoy
# Processing Record 10 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 2 | bukoba
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | fairbanks
# Processing Record 14 of Set 2 | codrington
# Processing Record 15 of Set 2 | tuatapere
# Processing Record 16 of Set 2 | karratha
# Processing Record 17 of Set 2 | papara
# Processing Record 18 of Set 2 | chuy
# Processing Record 19 of Set 2 | butaritari
# Processing Record 20 of Set 2 | oksfjord
# Processing Record 21 of Set 2 | tasiilaq
# Processing Record 22 of Set 2 | thompson
# Processing Record 23 of Set 2 | bethel
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | pangkalanbuun
# Processing Record 26 of Set 2 | yinchuan
# Processing Record 27 of Set 2 | port hardy
# Processing Record 28 of Set 2 | tura
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | tiarei
# Processing Record 31 of Set 2 | vung tau
# Processing Record 32 of Set 2 | bisert
# Processing Record 33 of Set 2 | shimoda
# Processing Record 34 of Set 2 | berlevag
# Processing Record 35 of Set 2 | inuvik
# Processing Record 36 of Set 2 | rocha
# Processing Record 37 of Set 2 | fredericksburg
# Processing Record 38 of Set 2 | bardiyah
# Processing Record 39 of Set 2 | gerede
# Processing Record 40 of Set 2 | bambous virieux
# Processing Record 41 of Set 2 | parras
# City not found. Skipping...
# Processing Record 42 of Set 2 | tual
# Processing Record 43 of Set 2 | cape town
# Processing Record 44 of Set 2 | cidreira
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | waipawa
# Processing Record 47 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 2 | san buenaventura
# Processing Record 49 of Set 2 | zyryanka
# Processing Record 50 of Set 2 | del rio
# Processing Record 1 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 3 | mabaruma
# Processing Record 3 of Set 3 | acajutla
# Processing Record 4 of Set 3 | byron bay
# Processing Record 5 of Set 3 | tornio
# Processing Record 6 of Set 3 | klyuchi
# Processing Record 7 of Set 3 | morristown
# Processing Record 8 of Set 3 | la ronge
# Processing Record 9 of Set 3 | mtimbira
# Processing Record 10 of Set 3 | diffa
# Processing Record 11 of Set 3 | tupiza
# Processing Record 12 of Set 3 | hofn
# Processing Record 13 of Set 3 | songjianghe
# Processing Record 14 of Set 3 | mataura
# Processing Record 15 of Set 3 | cajnice
# Processing Record 16 of Set 3 | changji
# Processing Record 17 of Set 3 | araouane
# Processing Record 18 of Set 3 | jalingo
# Processing Record 19 of Set 3 | sao miguel do araguaia
# Processing Record 20 of Set 3 | ribeira grande
# Processing Record 21 of Set 3 | bathsheba
# Processing Record 22 of Set 3 | dawson creek
# Processing Record 23 of Set 3 | mana
# Processing Record 24 of Set 3 | talnakh
# Processing Record 25 of Set 3 | busselton
# Processing Record 26 of Set 3 | nalut
# Processing Record 27 of Set 3 | itarema
# Processing Record 28 of Set 3 | batemans bay
# Processing Record 29 of Set 3 | athabasca
# Processing Record 30 of Set 3 | etawah
# Processing Record 31 of Set 3 | sarkand
# Processing Record 32 of Set 3 | cherskiy
# Processing Record 33 of Set 3 | pangnirtung
# Processing Record 34 of Set 3 | meulaboh
# Processing Record 35 of Set 3 | borisoglebskiy
# Processing Record 36 of Set 3 | umm lajj
# Processing Record 37 of Set 3 | buckeye
# Processing Record 38 of Set 3 | mnogovershinnyy
# Processing Record 39 of Set 3 | klaksvik
# Processing Record 40 of Set 3 | hobart
# Processing Record 41 of Set 3 | petrolina
# Processing Record 42 of Set 3 | chikwawa
# Processing Record 43 of Set 3 | panaba
# Processing Record 44 of Set 3 | melipilla
# Processing Record 45 of Set 3 | baturaja
# Processing Record 46 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 3 | soe
# Processing Record 48 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 3 | bondo
# Processing Record 50 of Set 3 | jiangyou
# Processing Record 1 of Set 4 | kangaatsiaq
# Processing Record 2 of Set 4 | grindavik
# Processing Record 3 of Set 4 | kavieng
# Processing Record 4 of Set 4 | lamesa
# Processing Record 5 of Set 4 | cartagena
# Processing Record 6 of Set 4 | yantai
# Processing Record 7 of Set 4 | cordeiro
# Processing Record 8 of Set 4 | kapaa
# Processing Record 9 of Set 4 | nishihara
# Processing Record 10 of Set 4 | airai
# Processing Record 11 of Set 4 | lewisporte
# Processing Record 12 of Set 4 | georgetown
# Processing Record 13 of Set 4 | hay river
# Processing Record 14 of Set 4 | duki
# Processing Record 15 of Set 4 | lagoa
# Processing Record 16 of Set 4 | alegrete
# Processing Record 17 of Set 4 | saskylakh
# Processing Record 18 of Set 4 | joshimath
# Processing Record 19 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 4 | anadyr
# Processing Record 21 of Set 4 | matay
# Processing Record 22 of Set 4 | wanning
# Processing Record 23 of Set 4 | brigantine
# Processing Record 24 of Set 4 | sandwick
# Processing Record 25 of Set 4 | tuktoyaktuk
# Processing Record 26 of Set 4 | rupert
# Processing Record 27 of Set 4 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 28 of Set 4 | college
# Processing Record 29 of Set 4 | souillac
# Processing Record 30 of Set 4 | lakes entrance
# Processing Record 31 of Set 4 | arraial do cabo
# Processing Record 32 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 4 | hit
# Processing Record 34 of Set 4 | biltine
# Processing Record 35 of Set 4 | east london
# Processing Record 36 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 37 of Set 4 | vila franca do campo
# Processing Record 38 of Set 4 | ilulissat
# Processing Record 39 of Set 4 | deori khas
# Processing Record 40 of Set 4 | faanui
# Processing Record 41 of Set 4 | matto
# City not found. Skipping...
# Processing Record 42 of Set 4 | carutapera
# Processing Record 43 of Set 4 | vilhena
# Processing Record 44 of Set 4 | chokurdakh
# Processing Record 45 of Set 4 | severo-kurilsk
# Processing Record 46 of Set 4 | kotido
# Processing Record 47 of Set 4 | tynset
# Processing Record 48 of Set 4 | cayenne
# Processing Record 49 of Set 4 | vao
# Processing Record 50 of Set 4 | predivinsk
# Processing Record 1 of Set 5 | meiganga
# Processing Record 2 of Set 5 | yulara
# Processing Record 3 of Set 5 | maloh
# Processing Record 4 of Set 5 | ancud
# Processing Record 5 of Set 5 | beringovskiy
# Processing Record 6 of Set 5 | jiuquan
# Processing Record 7 of Set 5 | wenatchee
# Processing Record 8 of Set 5 | churapcha
# Processing Record 9 of Set 5 | sorland
# Processing Record 10 of Set 5 | basoko
# Processing Record 11 of Set 5 | mar del plata
# Processing Record 12 of Set 5 | san patricio
# Processing Record 13 of Set 5 | mus
# Processing Record 14 of Set 5 | yellowknife
# Processing Record 15 of Set 5 | saint george
# Processing Record 16 of Set 5 | kakching
# Processing Record 17 of Set 5 | katsuura
# Processing Record 18 of Set 5 | khandbari
# Processing Record 19 of Set 5 | agadez
# Processing Record 20 of Set 5 | pisco
# Processing Record 21 of Set 5 | buon me thuot
# City not found. Skipping...
# Processing Record 22 of Set 5 | salalah
# Processing Record 23 of Set 5 | calbuco
# Processing Record 24 of Set 5 | presidencia roque saenz pena
# Processing Record 25 of Set 5 | castro
# Processing Record 26 of Set 5 | komsomolskiy
# Processing Record 27 of Set 5 | shingu
# Processing Record 28 of Set 5 | havoysund
# Processing Record 29 of Set 5 | axim
# Processing Record 30 of Set 5 | milingimbi
# City not found. Skipping...
# Processing Record 31 of Set 5 | inyonga
# Processing Record 32 of Set 5 | genhe
# Processing Record 33 of Set 5 | alexandria
# Processing Record 34 of Set 5 | russell
# Processing Record 35 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 5 | porto novo
# Processing Record 37 of Set 5 | thinadhoo
# Processing Record 38 of Set 5 | kaitangata
# Processing Record 39 of Set 5 | daru
# Processing Record 40 of Set 5 | lemesos
# City not found. Skipping...
# Processing Record 41 of Set 5 | milkovo
# Processing Record 42 of Set 5 | arroyo
# Processing Record 43 of Set 5 | nyurba
# Processing Record 44 of Set 5 | samfya
# Processing Record 45 of Set 5 | honningsvag
# Processing Record 46 of Set 5 | tawang
# Processing Record 47 of Set 5 | nanchang
# Processing Record 48 of Set 5 | ossora
# Processing Record 49 of Set 5 | alofi
# Processing Record 50 of Set 5 | lorengau
# Processing Record 1 of Set 6 | kilindoni
# Processing Record 2 of Set 6 | moncton
# Processing Record 3 of Set 6 | nushki
# Processing Record 4 of Set 6 | acapulco
# Processing Record 5 of Set 6 | xiongshi
# City not found. Skipping...
# Processing Record 6 of Set 6 | yeniseysk
# Processing Record 7 of Set 6 | san carlos
# Processing Record 8 of Set 6 | guerrero negro
# Processing Record 9 of Set 6 | loiza
# Processing Record 10 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 11 of Set 6 | leningradskiy
# Processing Record 12 of Set 6 | puerto maldonado
# Processing Record 13 of Set 6 | praia da vitoria
# Processing Record 14 of Set 6 | malandag
# Processing Record 15 of Set 6 | port blair
# Processing Record 16 of Set 6 | fomboni
# Processing Record 17 of Set 6 | morant bay
# Processing Record 18 of Set 6 | baiyin
# Processing Record 19 of Set 6 | port elizabeth
# Processing Record 20 of Set 6 | san francisco
# Processing Record 21 of Set 6 | san cristobal
# Processing Record 22 of Set 6 | rio grande
# Processing Record 23 of Set 6 | newport
# Processing Record 24 of Set 6 | jizan
# Processing Record 25 of Set 6 | grand gaube
# Processing Record 26 of Set 6 | suntar
# Processing Record 27 of Set 6 | mahebourg
# Processing Record 28 of Set 6 | natal
# Processing Record 29 of Set 6 | skiros
# City not found. Skipping...
# Processing Record 30 of Set 6 | estelle
# Processing Record 31 of Set 6 | vuktyl
# Processing Record 32 of Set 6 | kedrovyy
# Processing Record 33 of Set 6 | cabo san lucas
# Processing Record 34 of Set 6 | marechal candido rondon
# Processing Record 35 of Set 6 | dobroye
# Processing Record 36 of Set 6 | lasa
# Processing Record 37 of Set 6 | caraquet
# Processing Record 38 of Set 6 | araguari
# Processing Record 39 of Set 6 | ponta do sol
# Processing Record 40 of Set 6 | hami
# Processing Record 41 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 42 of Set 6 | asau
# Processing Record 43 of Set 6 | lower burrell
# Processing Record 44 of Set 6 | lahij
# Processing Record 45 of Set 6 | champerico
# Processing Record 46 of Set 6 | valdivia
# Processing Record 47 of Set 6 | san borja
# Processing Record 48 of Set 6 | burgeo
# Processing Record 49 of Set 6 | nador
# Processing Record 50 of Set 6 | sao filipe
# Processing Record 1 of Set 7 | yumen
# Processing Record 2 of Set 7 | port-cartier
# Processing Record 3 of Set 7 | lalomanu
# City not found. Skipping...
# Processing Record 4 of Set 7 | henties bay
# Processing Record 5 of Set 7 | ciudad bolivar
# Processing Record 6 of Set 7 | mount gambier
# Processing Record 7 of Set 7 | grenville
# Processing Record 8 of Set 7 | mangrol
# Processing Record 9 of Set 7 | walvis bay
# Processing Record 10 of Set 7 | leh
# Processing Record 11 of Set 7 | pevek
# Processing Record 12 of Set 7 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 13 of Set 7 | broken hill
# Processing Record 14 of Set 7 | sao joao da barra
# Processing Record 15 of Set 7 | pouembout
# Processing Record 16 of Set 7 | esperance
# Processing Record 17 of Set 7 | alyangula
# Processing Record 18 of Set 7 | manggar
# Processing Record 19 of Set 7 | gorontalo
# Processing Record 20 of Set 7 | murmino
# Processing Record 21 of Set 7 | cananeia
# Processing Record 22 of Set 7 | ixtapa
# Processing Record 23 of Set 7 | killarney
# Processing Record 24 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 7 | diamantina
# Processing Record 26 of Set 7 | beyneu
# Processing Record 27 of Set 7 | dulce nombre de culmi
# Processing Record 28 of Set 7 | atambua
# Processing Record 29 of Set 7 | general roca
# Processing Record 30 of Set 7 | oudtshoorn
# Processing Record 31 of Set 7 | los llanos de aridane
# Processing Record 32 of Set 7 | barberino di mugello
# Processing Record 33 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 34 of Set 7 | verkhnevilyuysk
# Processing Record 35 of Set 7 | griffith
# Processing Record 36 of Set 7 | alugan
# Processing Record 37 of Set 7 | smithers
# Processing Record 38 of Set 7 | husavik
# Processing Record 39 of Set 7 | uglovskoye
# Processing Record 40 of Set 7 | hasaki
# Processing Record 41 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 42 of Set 7 | bilibino
# Processing Record 43 of Set 7 | meadow lake
# Processing Record 44 of Set 7 | longyearbyen
# Processing Record 45 of Set 7 | qasigiannguit
# Processing Record 46 of Set 7 | banda aceh
# Processing Record 47 of Set 7 | aksarka
# Processing Record 48 of Set 7 | simao
# Processing Record 49 of Set 7 | hithadhoo
# Processing Record 50 of Set 7 | gizo
# Processing Record 1 of Set 8 | gao
# Processing Record 2 of Set 8 | norman wells
# Processing Record 3 of Set 8 | chazuta
# Processing Record 4 of Set 8 | zhezkazgan
# Processing Record 5 of Set 8 | zhangye
# Processing Record 6 of Set 8 | viedma
# Processing Record 7 of Set 8 | tessalit
# Processing Record 8 of Set 8 | mahanoro
# Processing Record 9 of Set 8 | andenes
# Processing Record 10 of Set 8 | saint-ambroise
# Processing Record 11 of Set 8 | yoichi
# Processing Record 12 of Set 8 | gedo
# Processing Record 13 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 8 | rio gallegos
# Processing Record 15 of Set 8 | marsa matruh
# Processing Record 16 of Set 8 | abu zabad
# Processing Record 17 of Set 8 | clarksburg
# Processing Record 18 of Set 8 | alihe
# Processing Record 19 of Set 8 | anloga
# Processing Record 20 of Set 8 | guaratinga
# Processing Record 21 of Set 8 | troyes
# Processing Record 22 of Set 8 | sokoni
# Processing Record 23 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 8 | parrita
# Processing Record 26 of Set 8 | inirida
# Processing Record 27 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 28 of Set 8 | krasnoselkup
# Processing Record 29 of Set 8 | pacifica
# Processing Record 30 of Set 8 | kalmunai
# Processing Record 31 of Set 8 | requena
# Processing Record 32 of Set 8 | mapiripan
# Processing Record 33 of Set 8 | aksu
# Processing Record 34 of Set 8 | mlonggo
# Processing Record 35 of Set 8 | wabag
# Processing Record 36 of Set 8 | muros
# Processing Record 37 of Set 8 | vandoeuvre-les-nancy
# Processing Record 38 of Set 8 | young
# Processing Record 39 of Set 8 | fort nelson
# Processing Record 40 of Set 8 | seoul
# Processing Record 41 of Set 8 | ostrovnoy
# Processing Record 42 of Set 8 | palmer
# Processing Record 43 of Set 8 | bengkulu
# Processing Record 44 of Set 8 | pimentel
# Processing Record 45 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 8 | bilma
# Processing Record 47 of Set 8 | stykkisholmur
# Processing Record 48 of Set 8 | dawlatabad
# Processing Record 49 of Set 8 | chapleau
# Processing Record 50 of Set 8 | buala
# Processing Record 1 of Set 9 | trinidad
# Processing Record 2 of Set 9 | iqaluit
# Processing Record 3 of Set 9 | pozo colorado
# Processing Record 4 of Set 9 | bermeo
# Processing Record 5 of Set 9 | pachperwa
# Processing Record 6 of Set 9 | foumban
# Processing Record 7 of Set 9 | huarmey
# Processing Record 8 of Set 9 | presidente epitacio
# Processing Record 9 of Set 9 | kodiak
# Processing Record 10 of Set 9 | darab
# Processing Record 11 of Set 9 | yanliang
# Processing Record 12 of Set 9 | flin flon
# Processing Record 13 of Set 9 | sukhobuzimskoye
# Processing Record 14 of Set 9 | marienburg
# Processing Record 15 of Set 9 | mata
# Processing Record 16 of Set 9 | coquimbo
# Processing Record 17 of Set 9 | iracoubo
# Processing Record 18 of Set 9 | kribi
# Processing Record 19 of Set 9 | phimai
# Processing Record 20 of Set 9 | gat
# Processing Record 21 of Set 9 | tateyama
# Processing Record 22 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 23 of Set 9 | bhatapara
# Processing Record 24 of Set 9 | turayf
# Processing Record 25 of Set 9 | yarmouth
# Processing Record 26 of Set 9 | benguela
# Processing Record 27 of Set 9 | torbay
# Processing Record 28 of Set 9 | parsabad
# Processing Record 29 of Set 9 | isla mujeres
# Processing Record 30 of Set 9 | morondava
# Processing Record 31 of Set 9 | bilopillya
# Processing Record 32 of Set 9 | poum
# Processing Record 33 of Set 9 | cape canaveral
# Processing Record 34 of Set 9 | mehamn
# Processing Record 35 of Set 9 | ust-nera
# Processing Record 36 of Set 9 | cervo
# Processing Record 37 of Set 9 | rieti
# Processing Record 38 of Set 9 | tromso
# Processing Record 39 of Set 9 | savinka
# Processing Record 40 of Set 9 | nimaparha
# Processing Record 41 of Set 9 | matara
# Processing Record 42 of Set 9 | blois
# Processing Record 43 of Set 9 | wajid
# Processing Record 44 of Set 9 | krasnogorsk
# Processing Record 45 of Set 9 | saint-francois
# Processing Record 46 of Set 9 | waingapu
# Processing Record 47 of Set 9 | kanniyakumari
# Processing Record 48 of Set 9 | coahuayana
# Processing Record 49 of Set 9 | grand-santi
# Processing Record 50 of Set 9 | mandalgovi
# Processing Record 1 of Set 10 | sogdiondon
# City not found. Skipping...
# Processing Record 2 of Set 10 | eureka
# Processing Record 3 of Set 10 | trairi
# Processing Record 4 of Set 10 | kokoda
# Processing Record 5 of Set 10 | luderitz
# Processing Record 6 of Set 10 | novopokrovka
# Processing Record 7 of Set 10 | vanderhoof
# Processing Record 8 of Set 10 | vila velha
# Processing Record 9 of Set 10 | alice springs
# Processing Record 10 of Set 10 | candido mendes
# Processing Record 11 of Set 10 | okhotsk
# Processing Record 12 of Set 10 | kindu
# Processing Record 13 of Set 10 | beitbridge
# Processing Record 14 of Set 10 | honiara
# Processing Record 15 of Set 10 | laguna
# Processing Record 16 of Set 10 | hellvik
# Processing Record 17 of Set 10 | chapais
# Processing Record 18 of Set 10 | nome
# Processing Record 19 of Set 10 | nordby
# Processing Record 20 of Set 10 | san andres
# Processing Record 21 of Set 10 | monrovia
# Processing Record 22 of Set 10 | nagato
# Processing Record 23 of Set 10 | gubkinskiy
# Processing Record 24 of Set 10 | bonavista
# Processing Record 25 of Set 10 | hyeres
# Processing Record 26 of Set 10 | miki
# Processing Record 27 of Set 10 | yuanping
# Processing Record 28 of Set 10 | beloha
# Processing Record 29 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 30 of Set 10 | sinnamary
# Processing Record 31 of Set 10 | isangel
# Processing Record 32 of Set 10 | nanchong
# Processing Record 33 of Set 10 | jinka
# Processing Record 34 of Set 10 | kavaratti
# Processing Record 35 of Set 10 | okha
# Processing Record 36 of Set 10 | aleksandrovskiy zavod
# Processing Record 37 of Set 10 | pacific grove
# Processing Record 38 of Set 10 | uniontown
# Processing Record 39 of Set 10 | mednogorskiy
# Processing Record 40 of Set 10 | batouri
# Processing Record 41 of Set 10 | narsaq
# Processing Record 42 of Set 10 | zhuhai
# Processing Record 43 of Set 10 | adavere
# Processing Record 44 of Set 10 | mosquera
# Processing Record 45 of Set 10 | solnechnyy
# Processing Record 46 of Set 10 | the valley
# Processing Record 47 of Set 10 | sioux lookout
# Processing Record 48 of Set 10 | barreirinhas
# Processing Record 49 of Set 10 | bunia
# Processing Record 50 of Set 10 | hervey bay
# Processing Record 1 of Set 11 | coihaique
# Processing Record 2 of Set 11 | sao jose da coroa grande
# Processing Record 3 of Set 11 | preeceville
# Processing Record 4 of Set 11 | richards bay
# Processing Record 5 of Set 11 | biak
# Processing Record 6 of Set 11 | bavleny
# Processing Record 7 of Set 11 | puerto del rosario
# Processing Record 8 of Set 11 | pokhara
# Processing Record 9 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 10 of Set 11 | kaffrine
# Processing Record 11 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 12 of Set 11 | mazagao
# Processing Record 13 of Set 11 | portland
# Processing Record 14 of Set 11 | kaeo
# Processing Record 15 of Set 11 | mayo
# Processing Record 16 of Set 11 | finschhafen
# Processing Record 17 of Set 11 | katherine
# Processing Record 18 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 19 of Set 11 | kahului
# Processing Record 20 of Set 11 | luyang
# Processing Record 21 of Set 11 | the pas
# Processing Record 22 of Set 11 | ambon
# Processing Record 23 of Set 11 | varberg
# Processing Record 24 of Set 11 | montbrison
# Processing Record 25 of Set 11 | bandar-e anzali
# Processing Record 26 of Set 11 | amberley
# Processing Record 27 of Set 11 | kurchum
# Processing Record 28 of Set 11 | road town
# Processing Record 29 of Set 11 | christchurch
# Processing Record 30 of Set 11 | kruisfontein
# Processing Record 31 of Set 11 | burnie
# Processing Record 32 of Set 11 | sisimiut
# Processing Record 33 of Set 11 | nueva loja
# Processing Record 34 of Set 11 | moindou
# Processing Record 35 of Set 11 | frolovo
# Processing Record 36 of Set 11 | borujan
# City not found. Skipping...
# Processing Record 37 of Set 11 | comodoro rivadavia
# Processing Record 38 of Set 11 | port lincoln
# Processing Record 39 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 41 of Set 11 | japura
# Processing Record 42 of Set 11 | nhulunbuy
# Processing Record 43 of Set 11 | bourail
# Processing Record 44 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 45 of Set 11 | doha
# Processing Record 46 of Set 11 | necochea
# Processing Record 47 of Set 11 | male
# Processing Record 48 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 50 of Set 11 | te anau
# Processing Record 1 of Set 12 | woodward
# Processing Record 2 of Set 12 | sao felix do xingu
# Processing Record 3 of Set 12 | yershichi
# Processing Record 4 of Set 12 | northam
# Processing Record 5 of Set 12 | fethiye
# Processing Record 6 of Set 12 | yenagoa
# Processing Record 7 of Set 12 | talaya
# Processing Record 8 of Set 12 | dunedin
# Processing Record 9 of Set 12 | kostomuksha
# Processing Record 10 of Set 12 | plettenberg bay
# Processing Record 11 of Set 12 | gomel
# Processing Record 12 of Set 12 | areosa
# Processing Record 13 of Set 12 | basarabeasca
# Processing Record 14 of Set 12 | hambantota
# Processing Record 15 of Set 12 | nata
# Processing Record 16 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 18 of Set 12 | syava
# Processing Record 19 of Set 12 | kidal
# Processing Record 20 of Set 12 | teguldet
# Processing Record 21 of Set 12 | fare
# Processing Record 22 of Set 12 | kisangani
# Processing Record 23 of Set 12 | magburaka
# Processing Record 24 of Set 12 | tecoanapa
# Processing Record 25 of Set 12 | buritis
# Processing Record 26 of Set 12 | micheweni
# Processing Record 27 of Set 12 | ewa beach
# Processing Record 28 of Set 12 | maniitsoq
# Processing Record 29 of Set 12 | porto belo
# Processing Record 30 of Set 12 | monaghan
# Processing Record 31 of Set 12 | shenjiamen
# Processing Record 32 of Set 12 | xingyi
# Processing Record 33 of Set 12 | san juan
# Processing Record 34 of Set 12 | pierre
# Processing Record 35 of Set 12 | bacolod
# Processing Record 36 of Set 12 | burns lake
# Processing Record 37 of Set 12 | gilgit
# Processing Record 38 of Set 12 | revda
# Processing Record 39 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 12 | akkermanovka
# Processing Record 41 of Set 12 | cabo rojo
# Processing Record 42 of Set 12 | zhengjiatun
# Processing Record 43 of Set 12 | yar-sale
# Processing Record 44 of Set 12 | ishigaki
# Processing Record 45 of Set 12 | diu
# Processing Record 46 of Set 12 | melk
# Processing Record 47 of Set 12 | khandwa
# Processing Record 48 of Set 12 | camacha
# Processing Record 49 of Set 12 | vanavara
# Processing Record 50 of Set 12 | nicoya
# Processing Record 1 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 13 | troitsko-pechorsk
# Processing Record 3 of Set 13 | half moon bay
# Processing Record 4 of Set 13 | wicklow
# Processing Record 5 of Set 13 | moche
# Processing Record 6 of Set 13 | toora-khem
# Processing Record 7 of Set 13 | quilmana
# Processing Record 8 of Set 13 | yaya
# Processing Record 9 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 10 of Set 13 | urumqi
# Processing Record 11 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 13 | koumac
# Processing Record 13 of Set 13 | berbera
# Processing Record 14 of Set 13 | nizwa
# Processing Record 15 of Set 13 | dingle
# Processing Record 16 of Set 13 | belyy yar
# Processing Record 17 of Set 13 | kiunga
# Processing Record 18 of Set 13 | mildura
# Processing Record 19 of Set 13 | urucara
# Processing Record 20 of Set 13 | olden
# Processing Record 21 of Set 13 | halifax
# Processing Record 22 of Set 13 | north bend
# Processing Record 23 of Set 13 | haapiti
# Processing Record 24 of Set 13 | jefferson city
# Processing Record 25 of Set 13 | fuxin
# Processing Record 26 of Set 13 | kajaani
# Processing Record 27 of Set 13 | visby
# Processing Record 28 of Set 13 | hualmay
# Processing Record 29 of Set 13 | flagstaff
# Processing Record 30 of Set 13 | ojinaga
# Processing Record 31 of Set 13 | marawi
# Processing Record 32 of Set 13 | tombouctou
# Processing Record 33 of Set 13 | egvekinot
# Processing Record 34 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 13 | coueron
# Processing Record 36 of Set 13 | taoudenni
# Processing Record 37 of Set 13 | sassandra
# Processing Record 38 of Set 13 | sitka
# Processing Record 39 of Set 13 | whitehorse
# Processing Record 40 of Set 13 | mbaiki
# Processing Record 41 of Set 13 | khambhaliya
# Processing Record 42 of Set 13 | medina
# Processing Record 43 of Set 13 | akcakoca
# Processing Record 44 of Set 13 | bocaranga
# City not found. Skipping...
# Processing Record 45 of Set 13 | shillong
# Processing Record 46 of Set 13 | lazaro cardenas
# Processing Record 47 of Set 13 | ahipara
# Processing Record 48 of Set 13 | sakakah
# Processing Record 49 of Set 13 | bangolo
# Processing Record 50 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 14 | cap malheureux
# Processing Record 2 of Set 14 | acari
# Processing Record 3 of Set 14 | urengoy
# Processing Record 4 of Set 14 | ferrol
# Processing Record 5 of Set 14 | mahajanga
# Processing Record 6 of Set 14 | tilichiki
# Processing Record 7 of Set 14 | parkes
# Processing Record 8 of Set 14 | sola
# Processing Record 9 of Set 14 | puksoozero
# Processing Record 10 of Set 14 | syracuse
# Processing Record 11 of Set 14 | bonfim
# Processing Record 12 of Set 14 | krumbach
# Processing Record 13 of Set 14 | arman
# Processing Record 14 of Set 14 | lata
# Processing Record 15 of Set 14 | tchaourou
# Processing Record 16 of Set 14 | tuxpan
# Processing Record 17 of Set 14 | flinders
# Processing Record 18 of Set 14 | luganville
# Processing Record 19 of Set 14 | salinopolis
# Processing Record 20 of Set 14 | srikakulam
# Processing Record 21 of Set 14 | saint-pierre
# Processing Record 22 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 14 | kabompo
# Processing Record 24 of Set 14 | sechura
# Processing Record 25 of Set 14 | acarau
# Processing Record 26 of Set 14 | ambanja
# Processing Record 27 of Set 14 | bestobe
# Processing Record 28 of Set 14 | santa maria
# Processing Record 29 of Set 14 | tochimilco
# Processing Record 30 of Set 14 | la union
# Processing Record 31 of Set 14 | macusani
# Processing Record 32 of Set 14 | bingol
# Processing Record 33 of Set 14 | khammam
# Processing Record 34 of Set 14 | frankfort
# Processing Record 35 of Set 14 | indramayu
# Processing Record 36 of Set 14 | mahon
# Processing Record 37 of Set 14 | yunjinghong
# City not found. Skipping...
# Processing Record 38 of Set 14 | wangjing
# Processing Record 39 of Set 14 | chachapoyas
# Processing Record 40 of Set 14 | westport
# Processing Record 41 of Set 14 | saharanpur
# Processing Record 42 of Set 14 | prince rupert
# Processing Record 43 of Set 14 | labuhan
# Processing Record 44 of Set 14 | praya
# Processing Record 45 of Set 14 | bubaque
# Processing Record 46 of Set 14 | balikpapan
# Processing Record 47 of Set 14 | noyabrsk
# Processing Record 48 of Set 14 | chardara
# Processing Record 49 of Set 14 | gambela
# Processing Record 50 of Set 14 | brae
# Processing Record 1 of Set 15 | lavrentiya
# Processing Record 2 of Set 15 | taksimo
# Processing Record 3 of Set 15 | botad
# Processing Record 4 of Set 15 | etchoropo
# Processing Record 5 of Set 15 | santa rosa
# Processing Record 6 of Set 15 | kenora
# Processing Record 7 of Set 15 | kedougou
# Processing Record 8 of Set 15 | bell ville
# Processing Record 9 of Set 15 | biala podlaska
# Processing Record 10 of Set 15 | san jose
# Processing Record 11 of Set 15 | jember
# Processing Record 12 of Set 15 | sarangani
# Processing Record 13 of Set 15 | laranjeiras do sul
# Processing Record 14 of Set 15 | severobaykalsk
# Processing Record 15 of Set 15 | vostok
# Processing Record 16 of Set 15 | benjamin constant
# Processing Record 17 of Set 15 | gushikawa
# Processing Record 18 of Set 15 | powell river
# Processing Record 19 of Set 15 | maraa
# Processing Record 20 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 21 of Set 15 | chengdu
# Processing Record 22 of Set 15 | bokovskaya
# Processing Record 23 of Set 15 | huiloapan
# Processing Record 24 of Set 15 | anqing
# Processing Record 25 of Set 15 | eydhafushi
# Processing Record 26 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 15 | emba
# Processing Record 28 of Set 15 | adrar
# Processing Record 29 of Set 15 | brownsville
# Processing Record 30 of Set 15 | olafsvik
# Processing Record 31 of Set 15 | khaga
# Processing Record 32 of Set 15 | pahrump
# Processing Record 33 of Set 15 | skjervoy
# Processing Record 34 of Set 15 | galveston
# Processing Record 35 of Set 15 | dourados
# Processing Record 36 of Set 15 | tiznit
# Processing Record 37 of Set 15 | saint-joseph
# Processing Record 38 of Set 15 | fillmore
# Processing Record 39 of Set 15 | saldanha
# Processing Record 40 of Set 15 | obo
# Processing Record 41 of Set 15 | scottsbluff
# Processing Record 42 of Set 15 | tingi
# Processing Record 43 of Set 15 | ornskoldsvik
# Processing Record 44 of Set 15 | azar shahr
# City not found. Skipping...
# Processing Record 45 of Set 15 | ahuimanu
# Processing Record 46 of Set 15 | mount isa
# Processing Record 47 of Set 15 | san vicente
# Processing Record 48 of Set 15 | rossland
# Processing Record 49 of Set 15 | akdepe
# Processing Record 50 of Set 15 | bobcaygeon
# Processing Record 1 of Set 16 | taltal
# Processing Record 2 of Set 16 | tautira
# Processing Record 3 of Set 16 | hearst
# Processing Record 4 of Set 16 | padang
# Processing Record 5 of Set 16 | pangoa
# Processing Record 6 of Set 16 | miri
# Processing Record 7 of Set 16 | avera
# Processing Record 8 of Set 16 | mariental
# Processing Record 9 of Set 16 | abnub
# Processing Record 10 of Set 16 | bitung
# Processing Record 11 of Set 16 | oistins
# Processing Record 12 of Set 16 | kamenka
# Processing Record 13 of Set 16 | pokosnoye
# Processing Record 14 of Set 16 | san quintin
# Processing Record 15 of Set 16 | truckee
# Processing Record 16 of Set 16 | sampit
# Processing Record 17 of Set 16 | tucuman
# Processing Record 18 of Set 16 | teya
# Processing Record 19 of Set 16 | hobyo
# Processing Record 20 of Set 16 | srednekolymsk
# Processing Record 21 of Set 16 | qabaqcol
# Processing Record 22 of Set 16 | kovdor
# Processing Record 23 of Set 16 | san ignacio
# Processing Record 24 of Set 16 | kenai
# Processing Record 25 of Set 16 | mbumi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia      AR -54.8000  -68.3000     31.66        86          40
# 1          Faya      SA  18.3851   42.4509     69.91        49          95
# 2  Punta Arenas      CL -53.1500  -70.9167     35.71        75          20
# 3     Jamestown      US  42.0970  -79.2353     81.95        63          75
# 4        Namibe      AO -15.1961   12.1522     63.36        85           1
# 5      Khatanga      RU  71.9667  102.5000     52.56        63         100
# 6    Nikolskoye      RU  59.7035   30.7861     73.29        72           0
# 7   Rio Formoso      BR  -8.6636  -35.1586     76.84        81          89
# 8          Hilo      US  19.7297 -155.0900     78.28       100          75
# 9        Atuona      PF  -9.8000 -139.0333     77.31        74          12
#
#    Wind Speed Current Description
# 0       25.32         shower snow
# 1        3.83     overcast clouds
# 2       27.63          few clouds
# 3       17.27       broken clouds
# 4        3.29           clear sky
# 5        8.88     overcast clouds
# 6        2.04           clear sky
# 7       11.10     overcast clouds
# 8        4.61                mist
# 9       16.11          few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia      AR -54.8000  -68.3000     31.66        86          40
# 1          Faya      SA  18.3851   42.4509     69.91        49          95
# 2  Punta Arenas      CL -53.1500  -70.9167     35.71        75          20
# 3     Jamestown      US  42.0970  -79.2353     81.95        63          75
# 4        Namibe      AO -15.1961   12.1522     63.36        85           1
# 5      Khatanga      RU  71.9667  102.5000     52.56        63         100
# 6    Nikolskoye      RU  59.7035   30.7861     73.29        72           0
# 7   Rio Formoso      BR  -8.6636  -35.1586     76.84        81          89
# 8          Hilo      US  19.7297 -155.0900     78.28       100          75
# 9        Atuona      PF  -9.8000 -139.0333     77.31        74          12
#
#    Wind Speed Current Description
# 0       25.32         shower snow
# 1        3.83     overcast clouds
# 2       27.63          few clouds
# 3       17.27       broken clouds
# 4        3.29           clear sky
# 5        8.88     overcast clouds
# 6        2.04           clear sky
# 7       11.10     overcast clouds
# 8        4.61                mist
# 9       16.11          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
